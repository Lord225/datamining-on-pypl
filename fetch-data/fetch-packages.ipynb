# %%
import urllib
import pandas as pd
import json
from bs4 import BeautifulSoup as bs
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
import urllib.request


TOP_PACKEGES_URL = "https://hugovk.github.io/top-pypi-packages/top-pypi-packages-30-days.min.json"

def get_top_packages():
    response = urllib.request.urlopen(TOP_PACKEGES_URL)

    data = response.read()

    packages = json.loads(data)
    metadata = packages['last_update']
    rows = packages['rows']

    data = pd.DataFrame(rows)

    print(f"Data from {metadata}")

    return data


packages = get_top_packages()

packages.head()
# Out:
# Data from 2024-10-01 11:28:00
#    download_count     project
# 0      1295883942       boto3
# 1       615425351     urllib3
# 2       518765013    botocore
# 3       515350549    requests
# 4       505945583  setuptools

# %%
packages.size
# Out:
# 16000

# %%
from tqdm.notebook import tqdm

base_pypl_url = "https://pypi.org/project/{}"

def get_repo_info(repo_name):
    url = base_pypl_url.format(repo_name)

    response = urllib.request.urlopen(url)

    html = response.read()

    bsObj = bs(html, features="html.parser")
    
    github = bsObj.find('a', href=lambda href: href and "github.com" in href)
    if github is not None:
        github_url = github['href']
    else:
        github_url = None

    if isinstance(github_url, list):
        return github_url[0]

    return github_url

SLICE_START = 0
SLICE_END = 10

# get first 1000 packages
repos = [get_repo_info(repo) for repo in tqdm(packages['project'][SLICE_START:SLICE_END])]
repos = [repo for repo in repos if repo is not None]

def strip(url: str):
    url = url.removeprefix("https://github.com/")

    # remove anything after first two slashes
    url = url.split("/")
    if len(url) > 2:
        url = "/".join(url[:2])
    else:
        url = "/".join(url)

    return url


repos = [strip(repo) for repo in repos]

print(f"Found {len(repos)} repos")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Found 10 repos

# %%
repos
# Out:
# ['boto/boto3',
#  'urllib3/urllib3',
#  'boto/botocore',
#  'psf/requests',
#  'pypa/setuptools',
#  'certifi/python-certifi',
#  'kjd/idna',
#  'Ousret/charset_normalizer',
#  'python/typing_extensions',
#  'dateutil/dateutil']

# %%
TOKEN = os.getenv("GITHUB_TOKEN")

def get_auth_headers():
    return {
        "Authorization": f"token {TOKEN}"
    }

# %%
# get repo info
base_github_url = "https://api.github.com/repos/{}"

# fetch repo info

def get_repo_info(repo_name):
    url = base_github_url.format(repo_name)

    request = urllib.request.Request(url, headers=get_auth_headers())

    response = urllib.request.urlopen(request)

    data = response.read()

    repo_info = json.loads(data)

    return repo_info

repo_info = [get_repo_info(repo) for repo in tqdm(repos)]

repo_info = pd.DataFrame(repo_info)

repo_info.head()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#           id                           node_id                name  \
# 0   24774658  MDEwOlJlcG9zaXRvcnkyNDc3NDY1OA==               boto3
# 1    2410676      MDEwOlJlcG9zaXRvcnkyNDEwNjc2             urllib3
# 2    6670942      MDEwOlJlcG9zaXRvcnk2NjcwOTQy            botocore
# 3    1362490      MDEwOlJlcG9zaXRvcnkxMzYyNDkw            requests
# 4   54980593  MDEwOlJlcG9zaXRvcnk1NDk4MDU5Mw==          setuptools
# 5    3060959      MDEwOlJlcG9zaXRvcnkzMDYwOTU5      python-certifi
# 6   10323585  MDEwOlJlcG9zaXRvcnkxMDMyMzU4NQ==                idna
# 7  200259335  MDEwOlJlcG9zaXRvcnkyMDAyNTkzMzU=  charset_normalizer
# 8  494077289                      R_kgDOHXMFaQ   typing_extensions
# 9   26876372  MDEwOlJlcG9zaXRvcnkyNjg3NjM3Mg==            dateutil
#
#                   full_name  private  \
# 0                boto/boto3    False
# 1           urllib3/urllib3    False
# 2             boto/botocore    False
# 3              psf/requests    False
# 4           pypa/setuptools    False
# 5    certifi/python-certifi    False
# 6                  kjd/idna    False
# 7  jawah/charset_normalizer    False
# 8  python/typing_extensions    False
# 9         dateutil/dateutil    False
#
#                                                owner  \
# 0  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 1  {'login': 'urllib3', 'id': 26825299, 'node_id'...
# 2  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 3  {'login': 'psf', 'id': 50630501, 'node_id': 'M...
# 4  {'login': 'pypa', 'id': 647025, 'node_id': 'MD...
# 5  {'login': 'certifi', 'id': 7292629, 'node_id':...
# 6  {'login': 'kjd', 'id': 34589, 'node_id': 'MDQ6...
# 7  {'login': 'jawah', 'id': 139072305, 'node_id':...
# 8  {'login': 'python', 'id': 1525981, 'node_id': ...
# 9  {'login': 'dateutil', 'id': 9849410, 'node_id'...
#
#                                       html_url  \
# 0                https://github.com/boto/boto3
# 1           https://github.com/urllib3/urllib3
# 2             https://github.com/boto/botocore
# 3              https://github.com/psf/requests
# 4           https://github.com/pypa/setuptools
# 5    https://github.com/certifi/python-certifi
# 6                  https://github.com/kjd/idna
# 7  https://github.com/jawah/charset_normalizer
# 8  https://github.com/python/typing_extensions
# 9         https://github.com/dateutil/dateutil
#
#                                          description   fork  \
# 0                                 AWS SDK for Python  False
# 1  urllib3 is a user-friendly HTTP client library...  False
# 2  The low-level, core functionality of boto3 and...  False
# 3               A simple, yet elegant, HTTP library.  False
# 4  Official project repository for the Setuptools...  False
# 5  (Python Distribution) A carefully curated coll...  False
# 6  Internationalized Domain Names for Python (IDN...  False
# 7   Truly universal encoding detector in pure Python  False
# 8  Backported and experimental type hints for Python  False
# 9  Useful extensions to the standard Python datet...  False
#
#                                                  url  ... forks open_issues  \
# 0            https://api.github.com/repos/boto/boto3  ...  1866         181
# 1       https://api.github.com/repos/urllib3/urllib3  ...  1147         126
# 2         https://api.github.com/repos/boto/botocore  ...  1087         134
# 3          https://api.github.com/repos/psf/requests  ...  9310         245
# 4       https://api.github.com/repos/pypa/setuptools  ...  1186         636
# 5  https://api.github.com/repos/certifi/python-ce...  ...   249           3
# 6              https://api.github.com/repos/kjd/idna  ...    91           5
# 7  https://api.github.com/repos/jawah/charset_nor...  ...    51           0
# 8  https://api.github.com/repos/python/typing_ext...  ...   106          22
# 9     https://api.github.com/repos/dateutil/dateutil  ...   489         383
#
#   watchers default_branch                                        permissions  \
# 0     9021        develop  {'admin': False, 'maintain': False, 'push': Fa...
# 1     3775           main  {'admin': False, 'maintain': False, 'push': Fa...
# 2     1486        develop  {'admin': False, 'maintain': False, 'push': Fa...
# 3    52087           main  {'admin': False, 'maintain': False, 'push': Fa...
# 4     2497           main  {'admin': False, 'maintain': False, 'push': Fa...
# 5      826         master  {'admin': False, 'maintain': False, 'push': Fa...
# 6      247         master  {'admin': False, 'maintain': False, 'push': Fa...
# 7      576         master  {'admin': False, 'maintain': False, 'push': Fa...
# 8      429           main  {'admin': False, 'maintain': False, 'push': Fa...
# 9     2348         master  {'admin': False, 'maintain': False, 'push': Fa...
#
#   temp_clone_token custom_properties  \
# 0                                 {}
# 1                                 {}
# 2                                 {}
# 3                                 {}
# 4                                 {}
# 5                                 {}
# 6                                NaN
# 7                                 {}
# 8                                 {}
# 9                                 {}
#
#                                         organization network_count  \
# 0  {'login': 'boto', 'id': 327752, 'node_id': 'MD...          1866
# 1  {'login': 'urllib3', 'id': 26825299, 'node_id'...          1147
# 2  {'login': 'boto', 'id': 327752, 'node_id': 'MD...          1087
# 3  {'login': 'psf', 'id': 50630501, 'node_id': 'M...          9310
# 4  {'login': 'pypa', 'id': 647025, 'node_id': 'MD...          1186
# 5  {'login': 'certifi', 'id': 7292629, 'node_id':...           249
# 6                                                NaN            91
# 7  {'login': 'jawah', 'id': 139072305, 'node_id':...            51
# 8  {'login': 'python', 'id': 1525981, 'node_id': ...           106
# 9  {'login': 'dateutil', 'id': 9849410, 'node_id'...           489
#
#   subscribers_count
# 0               234
# 1               101
# 2                68
# 3              1327
# 4                98
# 5                39
# 6                15
# 7                 9
# 8                18
# 9                47
#
# [10 rows x 85 columns]

# %%
def get_branch_info(repo) -> dict | None:
    url = repo['branches_url'].replace("{/branch}", "")
    default_branch = repo['default_branch']

    PREFERED_BRANCHES = ["master", "main", "develop"]
    request = urllib.request.Request(url, headers={"Authorization": f"token {TOKEN}"})
    response = urllib.request.urlopen(request)

    data = response.read()

    branches = json.loads(data)

    branches = [branch for branch in branches if branch['name'] in PREFERED_BRANCHES]

    if len(branches) == 0:
        branches = [branch for branch in branches if branch['name'] == default_branch]

    if len(branches) == 0:
        return None

    return branches[0]

branches = [get_branch_info(repo) for repo in tqdm(repo_info.to_dict(orient="records")) if repo is not None]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
branch_name = [(branch['name'] if branch is not None else None) for branch in branches]
branch_url = [(branch['commit']['url'] if branch is not None else None) for branch in branches]


repo_info['branch_name'] = branch_name
repo_info['branch_url'] = branch_url

# %%
# save as csv
repo_info.to_csv(f"repo_info-{SLICE_START}-{SLICE_END}.csv")
repo_info.head()
# Out:
#          id                           node_id        name        full_name  \
# 0  24774658  MDEwOlJlcG9zaXRvcnkyNDc3NDY1OA==       boto3       boto/boto3
# 1   2410676      MDEwOlJlcG9zaXRvcnkyNDEwNjc2     urllib3  urllib3/urllib3
# 2   6670942      MDEwOlJlcG9zaXRvcnk2NjcwOTQy    botocore    boto/botocore
# 3   1362490      MDEwOlJlcG9zaXRvcnkxMzYyNDkw    requests     psf/requests
# 4  54980593  MDEwOlJlcG9zaXRvcnk1NDk4MDU5Mw==  setuptools  pypa/setuptools
#
#    private                                              owner  \
# 0    False  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 1    False  {'login': 'urllib3', 'id': 26825299, 'node_id'...
# 2    False  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 3    False  {'login': 'psf', 'id': 50630501, 'node_id': 'M...
# 4    False  {'login': 'pypa', 'id': 647025, 'node_id': 'MD...
#
#                              html_url  \
# 0       https://github.com/boto/boto3
# 1  https://github.com/urllib3/urllib3
# 2    https://github.com/boto/botocore
# 3     https://github.com/psf/requests
# 4  https://github.com/pypa/setuptools
#
#                                          description   fork  \
# 0                                 AWS SDK for Python  False
# 1  urllib3 is a user-friendly HTTP client library...  False
# 2  The low-level, core functionality of boto3 and...  False
# 3               A simple, yet elegant, HTTP library.  False
# 4  Official project repository for the Setuptools...  False
#
#                                             url  ... watchers default_branch  \
# 0       https://api.github.com/repos/boto/boto3  ...     9021        develop
# 1  https://api.github.com/repos/urllib3/urllib3  ...     3775           main
# 2    https://api.github.com/repos/boto/botocore  ...     1486        develop
# 3     https://api.github.com/repos/psf/requests  ...    52087           main
# 4  https://api.github.com/repos/pypa/setuptools  ...     2497           main
#
#                                          permissions temp_clone_token  \
# 0  {'admin': False, 'maintain': False, 'push': Fa...
# 1  {'admin': False, 'maintain': False, 'push': Fa...
# 2  {'admin': False, 'maintain': False, 'push': Fa...
# 3  {'admin': False, 'maintain': False, 'push': Fa...
# 4  {'admin': False, 'maintain': False, 'push': Fa...
#
#   custom_properties                                       organization  \
# 0                {}  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 1                {}  {'login': 'urllib3', 'id': 26825299, 'node_id'...
# 2                {}  {'login': 'boto', 'id': 327752, 'node_id': 'MD...
# 3                {}  {'login': 'psf', 'id': 50630501, 'node_id': 'M...
# 4                {}  {'login': 'pypa', 'id': 647025, 'node_id': 'MD...
#
#   network_count subscribers_count branch_name  \
# 0          1866               234     develop
# 1          1147               101        main
# 2          1087                68     develop
# 3          9310              1327        main
# 4          1186                98        None
#
#                                           branch_url
# 0  https://api.github.com/repos/boto/boto3/commit...
# 1  https://api.github.com/repos/urllib3/urllib3/c...
# 2  https://api.github.com/repos/boto/botocore/com...
# 3  https://api.github.com/repos/psf/requests/comm...
# 4                                               None
#
# [5 rows x 87 columns]
