# %%
import h5py
import numpy as np

embeddings = np.load('./embeddings.npy', allow_pickle=True)
embeddings
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
indices = np.arange(len(embeddings))
embeddings_array = np.array([list(map(float, embedding)) for embedding in embeddings[:-1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 indices = np.arange(len(embeddings))
#       2 embeddings_array = np.array([list(map(float, embedding)) for embedding in embeddings[:-1]])
# ----> 3 embeddings_with_indices = np.column_stack((indices, embeddings_array))
#       4 embeddings_with_indices
#
# File c:\Users\Maciej\miniconda3\envs\torch\lib\site-packages\numpy\lib\_shape_base_impl.py:674, in column_stack(tup)
#     672         arr = array(arr, copy=None, subok=True, ndmin=2).T
#     673     arrays.append(arr)
# --> 674 return _nx.concatenate(arrays, 1)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 551658 and the array at index 1 has size 551657

# %%
# save embeddings to hdf5 using pandas
import pandas as pd
df = pd.DataFrame(embeddings_array)
df.to_hdf('embeddings.h5', key='embeddings', mode='w', format='table')
